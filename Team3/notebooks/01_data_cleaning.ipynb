# %% [markdown]
# # 01 - Data Cleaning
#
# **Team3 - Singapore Jobs Analytics**
#
# This notebook handles loading and cleaning the raw CSV dataset (~1M+ rows).
#
# ## Steps
# 1. Load raw CSV
# 2. Handle missing values
# 3. Standardise categories
# 4. Parse dates
# 5. Handle salary formats
# 6. Export cleaned data to `data/processed/`

# %%
import pandas as pd
import numpy as np
import os

# %%
# Load raw data
# df = pd.read_csv('../data/raw/your_dataset.csv')
