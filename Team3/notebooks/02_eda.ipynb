# %% [markdown]
# # 02 - Exploratory Data Analysis (EDA)
#
# **Team3 - Singapore Jobs Analytics**
#
# This notebook explores the cleaned dataset to discover key patterns and anomalies.
#
# ## Areas to Explore
# - Distribution of job postings by role, industry, location
# - Salary range analysis
# - Time trends in job postings
# - Skills demand patterns
# - Key insights that will shape the dashboard design

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load cleaned data
# df = pd.read_csv('../data/processed/cleaned_jobs.csv')
