# %% [markdown]
# # 03 - Feature Engineering
#
# **Team3 - Singapore Jobs Analytics**
#
# This notebook creates derived features for the dashboard.
#
# ## Features to Engineer
# - Seniority level extraction
# - Salary bands
# - Demand metrics
# - Skill tags
# - Other derived columns as needed

# %%
import pandas as pd
import numpy as np

# %%
# Load cleaned data
# df = pd.read_csv('../data/processed/cleaned_jobs.csv')
